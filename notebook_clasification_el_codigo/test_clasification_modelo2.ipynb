# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf

modelo = tf.keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/clasificacion imagenes Redes neuronales/save_model/best_model_3_1.keras')
# Out:
# WARNING:absl:Skipping variable loading for optimizer 'Adam', because it has 435 variables whereas the saved optimizer has 1 variables.

# %%
test_dir = "/content/drive/MyDrive/Colab Notebooks/clasificacion imagenes Redes neuronales/dataset/test"

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

test_datagen = ImageDataGenerator(rescale=1.0/255)

test_data = test_datagen.flow_from_directory(test_dir,
                                            target_size=(224, 224),
                                            batch_size=32,
                                            class_mode='categorical')
# Out:
# Found 150 images belonging to 3 classes.

# %%
evaluation = modelo.evaluate(test_data)
# Out:
# 5/5 [==============================] - 15s 2s/step - loss: 0.4529 - accuracy: 0.9267

# %%
print("Pérdida en datos de prueba:", evaluation[0])
print("Precisión en datos de prueba:", evaluation[1])
# Out:
# Pérdida en datos de prueba: 0.4529256224632263
# Precisión en datos de prueba: 0.9266666769981384
