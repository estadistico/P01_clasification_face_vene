# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf

modelo = tf.keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/clasificacion imagenes Redes neuronales/save_model/modelo_1_final2.h5')

# %%
test_dir = "/content/drive/MyDrive/Colab Notebooks/clasificacion imagenes Redes neuronales/dataset/test"

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

test_datagen = ImageDataGenerator(rescale=1.0/255)

test_data = test_datagen.flow_from_directory(test_dir,
                                            target_size=(224, 224),
                                            batch_size=32,
                                            class_mode='categorical')
# Out:
# Found 150 images belonging to 3 classes.

# %%
evaluation = modelo.evaluate(test_data)
# Out:
# 5/5 [==============================] - 30s 7s/step - loss: 0.0108 - accuracy: 0.9933

# %%
print("Pérdida en datos de prueba:", evaluation[0])
print("Precisión en datos de prueba:", evaluation[1])
# Out:
# Pérdida en datos de prueba: 0.010818465612828732
# Precisión en datos de prueba: 0.9933333396911621
